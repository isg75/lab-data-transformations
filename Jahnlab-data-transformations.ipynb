# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mca2 = pd.read_csv("/Users/jxhn/Desktop/IRONHACK/Week_1/Day_4/Morning/Jahn-lab-dw-data-structuring-and-combining/mca.csv")
mca2 = mca2.drop('Unnamed: 0', axis=1)
mca2 = mca2.drop('unnamed:_0', axis=1)
mca2.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#      datetime employmentstatus gender  income  ... number_of_policies  \
# 0  2011-02-18         Employed      M   48029  ...                  9
# 1  2011-01-18       Unemployed      F       0  ...                  1
# 2  2011-02-10         Employed      M   22139  ...                  2
# 3  2011-01-11         Employed      M   49078  ...                  2
# 4  2011-01-17    Medical Leave      F   23675  ...                  7
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# ...

# %%
mca2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10910 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10910 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   datetime                       10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
mca2.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             10910.000000  10910.000000          10910.000000
# mean               8018.241094  37536.284785             93.196059
# std                6885.081434  30359.195670             34.442532
# min                1898.007675      0.000000             61.000000
# 25%                4014.453113      0.000000             68.000000
# 50%                5771.147235  33813.500000             83.000000
# 75%                8992.779137  62250.750000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count             10910.000000                   10910.000000
# mean                 15.149071                      48.091934
# std                   9.783520                      27.940675
# min                   0.000000                       0.000000
# ...

# %%
sns.displot(mca2['response'])
plt.show()

# %%
df_numeric = mca2.select_dtypes(include=[np.number]).copy()


df_object = mca2.select_dtypes(include=[np.object]).copy()
# Out:
# /var/folders/h1/sm0yz6nx7m9cgsn8627qx6c00000gn/T/ipykernel_98301/2928721649.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_object = mca2.select_dtypes(include=[np.object]).copy()

# %%
df_numeric
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                     7.000000                             52
# 1                     3.000000                             26
# ...

# %%
df_object
# Out:
#       customer       state response  coverage education    datetime  \
# 0      DK49336     Arizona       No     Basic   College  2011-02-18
# 1      KX64629  California       No     Basic   College  2011-01-18
# 2      LZ68649  Washington       No     Basic  Bachelor  2011-02-10
# 3      XL78013      Oregon      Yes  Extended   College  2011-01-11
# 4      QA50777      Oregon       No   Premium  Bachelor  2011-01-17
# ...        ...         ...      ...       ...       ...         ...
# 10905  FE99816      Nevada       No   Premium  Bachelor  2011-01-19
# 10906  KX53892      Oregon       No     Basic   College  2011-01-06
# 10907  TL39050     Arizona       No  Extended  Bachelor  2011-02-06
# 10908  WA60547  California       No   Premium   College  2011-02-13
# 10909  IV32877     unknown  unknown     Basic  Bachelor  2011-01-08
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
sns.displot(mca2['customer_lifetime_value'])
plt.show()

# %%
sns.displot(mca2['income'])
plt.show()

# %%
sns.displot(mca2['monthly_premium_auto'])
plt.show()

# %%
sns.displot(mca2['months_since_last_claim'])
plt.show()

# %%
sns.displot(mca2['months_since_policy_inception'])
plt.show()

# %%
sns.displot(mca2['number_of_open_complaints'])
plt.show()

# %%
sns.displot(mca2['number_of_policies'])
plt.show()

# %%
sns.displot(mca2['total_claim_amount'])
plt.show()

# %%
mca2['customer_lifetime_value'].hist(bins=50)
plt.show()

# %%
mca2['income'].hist(bins=50)
plt.show()

# %%
mca2['monthly_premium_auto'].hist(bins=100)
plt.show()

# %%
mca2['months_since_last_claim'].hist(bins=20)
plt.show()

# %%
mca2['months_since_policy_inception'].hist(bins=100)
plt.show()

# %%
mca2['number_of_open_complaints'].hist(bins=50)
plt.show()

# %%
mca2['number_of_open_complaints'].hist(bins=50)
plt.show()

# %%
mca2['number_of_policies'].hist(bins=50)
plt.show()

# %%
mca2['total_claim_amount'].hist(bins=50)
plt.show()

# %%
df_numeric.columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies',
#        'total_claim_amount'],
#       dtype='object')

# %%
print(mca2['customer_lifetime_value'].skew())
print("which is outside the [-2,2] range.")
# Out:
# 3.001047336521593
# which is outside the [-2,2] range.

# %%
print(mca2['income'].skew())
print("which is outside the [-2,2] range.")
# Out:
# 0.2858390930328839
# which is outside the [-2,2] range.

# %%
print(mca2['monthly_premium_auto'].skew())
print("which is outside the [-2,2] range.")
# Out:
# 2.1165667204838683
# which is outside the [-2,2] range.

# %%
print(mca2['months_since_last_claim'].skew())
print("which is outside the [-2,2] range.")
# Out:
# 0.27852590912867176
# which is outside the [-2,2] range.

# %%
print(mca2['months_since_policy_inception'].skew())
print("which is outside the [-2,2] range.")
# Out:
# 0.03364188297216199
# which is outside the [-2,2] range.

# %%
print(mca2['number_of_open_complaints'].skew())
print("which is outside the [-2,2] range.")
# Out:
# 2.8887622619249638
# which is outside the [-2,2] range.

# %%
print(mca2['number_of_policies'].skew())
print("which is inside the [-2,2] range.")
# Out:
# 1.2425740654009907
# which is inside the [-2,2] range.

# %%
print(mca2['total_claim_amount'].skew())
print("which is inside the [-2,2] range.")
# Out:
# 1.7292858027409794
# which is inside the [-2,2] range.

# %%
correlation_matrix = df_numeric.corr()

# %%
correlation_matrix
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.028306
# income                                        0.028306  1.000000
# monthly_premium_auto                          0.403069 -0.009788
# months_since_last_claim                       0.015683 -0.023126
# months_since_policy_inception                 0.016960 -0.005903
# number_of_open_complaints                    -0.031501  0.006956
# number_of_policies                            0.016024 -0.009960
# total_claim_amount                            0.232626 -0.354141
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.403069                 0.015683
# income                                    -0.009788                -0.023126
# monthly_premium_auto                       1.000000                 0.008504
# ...

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
